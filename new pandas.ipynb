# %%
import pandas as pd
data=pd.read_excel(r"C:\Users\kavidass\Downloads\students_500_with_nulls.xlsx")
print(data)


#df=pd.DataFrame(data)



df["Tamil"].fillna(a1,inplace=True)
df["Maths"].fillna(a3,inplace=True)
df["English"].fillna(a2,inplace=True)
df["Science"].fillna(a4,inplace=True)
df["Social Science"].fillna(a5,inplace=True)
df["total"].fillna(a6,inplace=True)
df["grade"].fillna(a7,inplace=True)
df["result"].fillna(a8,inplace=True)
# Out:
#        student_name  Tamil  English  Maths  Science  Social Science  total  \
# 0         Priya Rao   59.0     87.0   42.0     93.0            59.0    340
# 1       Harsha Khan   36.0     39.0   56.0     70.0             NaN    201
# 2         Meera Das   40.0     68.0   70.0     61.0            63.0    302
# 3    Harsha Nambiar   75.0     72.0   48.0     87.0            74.0    356
# 4      Priya Shetty   84.0     62.0   77.0     46.0            58.0    327
# ..              ...    ...      ...    ...      ...             ...    ...
# 495   Vikram Sharma   69.0     52.0    NaN     78.0            39.0    238
# 496       Sai Balan   70.0     51.0   75.0     49.0            44.0    289
# 497    Isha Nambiar   58.0     81.0   28.0     96.0            86.0    349
# 498      Isha Gupta   75.0     76.0   68.0     66.0            71.0    356
# 499   Rahul Karthik   66.0     89.0   44.0     60.0            75.0    334
#
#      percentage grade result
# 0          68.0     C   Pass
# ...

# %%
df=pd.DataFrame(data)
print(df)
# Out:
#        student_name  Tamil  English  Maths  Science  Social Science  total  \
# 0         Priya Rao   59.0     87.0   42.0     93.0            59.0    340
# 1       Harsha Khan   36.0     39.0   56.0     70.0             NaN    201
# 2         Meera Das   40.0     68.0   70.0     61.0            63.0    302
# 3    Harsha Nambiar   75.0     72.0   48.0     87.0            74.0    356
# 4      Priya Shetty   84.0     62.0   77.0     46.0            58.0    327
# ..              ...    ...      ...    ...      ...             ...    ...
# 495   Vikram Sharma   69.0     52.0    NaN     78.0            39.0    238
# 496       Sai Balan   70.0     51.0   75.0     49.0            44.0    289
# 497    Isha Nambiar   58.0     81.0   28.0     96.0            86.0    349
# 498      Isha Gupta   75.0     76.0   68.0     66.0            71.0    356
# 499   Rahul Karthik   66.0     89.0   44.0     60.0            75.0    334
#
#      percentage grade result
# 0          68.0     C   Pass
# ...

# %%
a1=df["Tamil"].mean()
a1
# Out:
# np.float64(63.84937238493724)

# %%
a2=df["English"].mean()
a2
# Out:
# np.float64(64.89079229122056)

# %%
a3=df["Maths"].mean()
a3
# Out:
# np.float64(64.69133192389006)

# %%
a4=df["Science"].mean()
a4
# Out:
# np.float64(64.40251572327044)

# %%
a5=df["Social Science"].mean()
a5
# Out:
# np.float64(65.06639004149378)

# %%
a6=df["total"].mean()
a6
# Out:
# np.float64(307.01)

# %%
a7=df["grade"].mode()
a7
# Out:
# 0    C
# Name: grade, dtype: object

# %%
a8=df["result"].mode()
a8
# Out:
# 0    Pass
# Name: result, dtype: object

# %%
df["Tamil"].fillna(a1,inplace=True)
df["Maths"].fillna(a3,inplace=True)
df["English"].fillna(a2,inplace=True)
df["Science"].fillna(a4,inplace=True)
df["Social Science"].fillna(a5,inplace=True)
df["total"].fillna(a6,inplace=True)
df["grade"].fillna(a7,inplace=True)
df["result"].fillna(a8,inplace=True)
df
# Out:
# C:\Users\kavidass\AppData\Local\Temp\ipykernel_12668\3808478496.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Tamil"].fillna(a1,inplace=True)
# C:\Users\kavidass\AppData\Local\Temp\ipykernel_12668\3808478496.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   student_name    500 non-null    object
#  1   Tamil           500 non-null    float64
#  2   English         500 non-null    float64
#  3   Maths           500 non-null    float64
#  4   Science         500 non-null    float64
#  5   Social Science  500 non-null    float64
#  6   total           500 non-null    int64
#  7   percentage      500 non-null    float64
#  8   grade           500 non-null    object
#  9   result          391 non-null    object
# dtypes: float64(6), int64(1), object(3)
# memory usage: 39.2+ KB

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder= LabelEncoder()

# %%
data["grade"]=label_encoder.fit_transform(data["grade"])
data["grade"]
# Out:
# 0      2
# 1      4
# 2      2
# 3      1
# 4      2
#       ..
# 495    4
# 496    3
# 497    2
# 498    1
# 499    2
# Name: grade, Length: 500, dtype: int64

# %%
data["result"]=label_encoder.fit_transform(data["result"])
data["result"]
# Out:
# 0      1
# 1      2
# 2      1
# 3      1
# 4      1
#       ..
# 495    2
# 496    1
# 497    0
# 498    1
# 499    1
# Name: result, Length: 500, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data1=data.drop(["student_name"],axis=1)
correlation_matrix = data1.corr()

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
x=data.drop(["student_name","total","percentage","grade","result"],axis=1)
y=data["total"]

# %%
x
# Out:
#      Tamil  English      Maths  Science  Social Science
# 0     59.0     87.0  42.000000     93.0        59.00000
# 1     36.0     39.0  56.000000     70.0        65.06639
# 2     40.0     68.0  70.000000     61.0        63.00000
# 3     75.0     72.0  48.000000     87.0        74.00000
# 4     84.0     62.0  77.000000     46.0        58.00000
# ..     ...      ...        ...      ...             ...
# 495   69.0     52.0  64.691332     78.0        39.00000
# 496   70.0     51.0  75.000000     49.0        44.00000
# 497   58.0     81.0  28.000000     96.0        86.00000
# 498   75.0     76.0  68.000000     66.0        71.00000
# 499   66.0     89.0  44.000000     60.0        75.00000
#
# [500 rows x 5 columns]

# %%
y
# Out:
# 0      340
# 1      201
# 2      302
# 3      356
# 4      327
#       ...
# 495    238
# 496    289
# 497    349
# 498    356
# 499    334
# Name: total, Length: 500, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train,y_test = train_test_split(x,y, test_size=0.2 ,random_state=42)

# %%
x_train.head()
# Out:
#      Tamil  English  Maths  Science  Social Science
# 249   74.0     65.0   69.0     32.0            86.0
# 433   62.0    100.0   79.0     79.0            53.0
# 19    81.0     58.0   30.0     85.0            47.0
# 322   57.0     39.0   61.0     38.0            34.0
# 332   59.0     54.0   71.0     79.0            62.0

# %%
y_train.head()
# Out:
# 249    326
# 433    373
# 19     301
# 322    229
# 332    325
# Name: total, dtype: int64

# %%
x_test.head()
# Out:
#      Tamil    English  Maths    Science  Social Science
# 361   75.0  79.000000   59.0  47.000000            71.0
# 73    82.0  64.890792   45.0  86.000000            45.0
# 374   57.0  67.000000   73.0  91.000000            50.0
# 155   76.0  43.000000   48.0  64.402516            91.0
# 104   58.0  61.000000   15.0  37.000000            60.0

# %%
y_test.head()
# Out:
# 361    331
# 73     258
# 374    338
# 155    258
# 104    231
# Name: total, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

model= LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train)   # X_train = features, y_train = target
# Out:
# LinearRegression()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   student_name    500 non-null    object
#  1   Tamil           500 non-null    float64
#  2   English         500 non-null    float64
#  3   Maths           500 non-null    float64
#  4   Science         500 non-null    float64
#  5   Social Science  500 non-null    float64
#  6   total           500 non-null    int64
#  7   percentage      500 non-null    float64
#  8   grade           500 non-null    object
#  9   result          391 non-null    object
# dtypes: float64(6), int64(1), object(3)
# memory usage: 39.2+ KB

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([315.74107696, 307.11804897, 322.48922542, 307.89671758,
#        217.5575665 , 296.76651324, 291.22203915, 297.3948144 ,
#        332.52695259, 300.05761427, 404.53914605, 296.40009595,
#        309.19279254, 327.72826133, 316.97617392, 255.9919253 ,
#        289.49549253, 269.46077474, 301.92844078, 186.87679158,
#        318.08732945, 314.08300405, 302.36456202, 363.13224696,
#        266.83539193, 296.04087842, 329.08638368, 341.22961507,
#        357.63946791, 263.59305221, 305.02072464, 237.90446193,
#        371.18934968, 353.40777519, 287.85910235, 297.47194251,
#        260.10102576, 342.77955473, 318.20262003, 301.96228048,
#        258.15827425, 359.47991469, 339.60737474, 349.56226722,
#        309.24206849, 234.76996764, 321.38558736, 342.93780333,
#        263.62462673, 268.12046854, 286.07188166, 345.47122678,
#        297.44554115, 302.90641621, 358.1208669 , 258.45710164,
#        302.95098344, 309.71487939, 360.92543941, 342.83471341,
# ...

# %%
y_test
# Out:
# 361    331
# 73     258
# 374    338
# 155    258
# 104    231
#       ...
# 347    297
# 86     280
# 75     279
# 438    241
# 15     320
# Name: total, Length: 100, dtype: int64

# %%
import joblib

joblib.dump(model, "batch1.pkl")
# Out:
# ['batch1.pkl']

# %%
import joblib

loade=joblib.load("batch1.pkl")

y_pred=loade.predict([[82,96,89,55,50]])
print(y_pred)
# Out:
# [356.42215384]
# C:\Users\kavidass\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
sum([82,96,89,55,50])
# Out:
# 372
